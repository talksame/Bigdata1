# %% [markdown]
# # 데이터 정리하기

# %% [markdown]
# # 데이터 불러오기

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 3s (3,414 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
#Colab에서 Drive Mounting 시키는 코드.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터 파일 받아오기
Festival  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/Festival_2019_csv.csv')
#훈련시킬 데이터 확인하기.
Festival.describe()
# Out:
#                연번
# count  225.000000
# mean   113.000000
# std     65.096083
# min      1.000000
# 25%     57.000000
# 50%    113.000000
# 75%    169.000000
# max    225.000000

# %%
Festival.head()
# Out:
#    연번  시도명 시군구명              축제명  ...  합 계  내국인  외국인                          개최장소
# 0   1  강원도  춘천시           춘천마임축제  ...  116  107    9                        극장, 공원
# 1   2  강원도  춘천시            봄내예술제  ...    9    9  NaN            야외공연장, \n극장, 갤러리 등
# 2   3  강원도  춘천시            춘천연극제  ...   16   15    0                        극장, 광장
# 3   4  강원도  춘천시           춘천인형극제  ...   67   67  NaN                        극장, 광장
# 4   5  강원도  춘천시  장난감축제\n(토이페스티벌)  ...    6    6  NaN  서면 애니메이션박물관, 인형극장, 글램핑장, 로봇관
#
# [5 rows x 21 columns]

# %%
print(Festival['2019년\n개최기간'][0].split('~'))
if '월 중' in Festival['2019년\n개최기간'][1] or '월중' in Festival['2019년\n개최기간'][1]:
  print(2)
  Festival['2019년\n개최기간'][1] = '10.1~10.31'.split('~')

print(Festival['2019년\n개최기간'][1])
# Out:
# ['04.05', '04.11']
# ['10.01', '10.31']

# %%
print(Festival['2019년\n개최기간'][0].split('~'))
if '~' in Festival['2019년\n개최기간'][0]:
  temp = Festival['2019년\n개최기간'][0].split('~')
  start_days = temp[0].split('.')
  start_day = "%s.%s"%(str(int(days[0])), str(int(days[1])))
  print(start_day)

  end_days = temp[1].split('.')
  end_day = "%s.%s"%(str(int(end_days[0])), str(int(end_days[1])))
  print(end_day)

  Festival['2019년\n개최기간'][0] = [start_day, end_day]
Festival['2019년\n개최기간'][0]
# Out:
# ['04.05', '04.11']
# 4.5
# 4.11
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# ['4.5', '4.11']

# %%
print(Festival['2019년\n개최기간'][325])
if '~' in Festival['2019년\n개최기간'][325]:
  temp = Festival['2019년\n개최기간'][325].split('~')
  if len(temp[0]) != 5 or len(temp[1]) != 5: 
    print(1) 
  print(temp)
# Out:
# 5.3~5.5
# 1
# ['5.3', '5.5']

# %%
print(Festival['2019년\n개최기간'][586].split('~'))
if '~' in Festival['2019년\n개최기간'][586]:
  temp = Festival['2019년\n개최기간'][586].split('~')
  start_days = temp[0].split('.')
  start_day = "%s.%s"%(str(int(start_days[0])), str(int(start_days[1])))
  print(start_day)

  end_days = temp[1].split('.')
  end_day = "%s.%s"%(str(int(end_days[0])), str(int(end_days[1])))
  print(end_day)

  Festival['2019년\n개최기간'][586] = [start_day, end_day]
Festival['2019년\n개최기간'][586]
# Out:
# ['5.4', '5.6']
# 5.4
# 5.6
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# ['5.4', '5.6']

# %%
Festival.sample(10)
# Out:
#         연번    시도명 시군구명  ...  외국인                           개최장소 Unnamed: 21
# 751   42.0   경상북도  영양군  ...    2                            NaN         NaN
# 691   89.0    NaN  NaN  ...    0         염산면 일원\n(설도항, 백바위해수욕장)         NaN
# 325   87.0    경기도  파주시  ...    0                파주출판도시\n광장, 축제장         NaN
# 586   34.0   전라북도  임실군  ...  NaN                             공원         NaN
# 702  100.0    NaN  NaN  ...  NaN  완도읍해변공원\n완도수목원\n완도타워 \n청산도 일원         NaN
# 556    4.0   전라북도  전주시  ...  NaN                        덕진공원 일대         NaN
# 611    9.0    NaN  NaN  ...  NaN                     소라면 \n장척마을         NaN
# 648   46.0    NaN  NaN  ...  NaN                          고흥만일원         NaN
# 693   91.0    NaN  NaN  ...  NaN       영광 노을전시관 일원(백수읍 해안로 957)         NaN
# 28    29.0  서울특별시  노원구  ...  NaN                             하천         NaN
#
# [10 rows x 22 columns]

# %%
# 데이터 파일 받아오기
Shopping  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 지역별 문화체육관광시설 인근 쇼핑시설(백화점, 면세점, 할인매장 등) 데이터.csv')
#훈련시킬 데이터 확인하기.
Shopping.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        sub_nm      mcate_cd  ...  lst_updt_dt    base_ymd
# count     0.0  74776.000000  ...      74776.0     74776.0
# mean      NaN  91147.354378  ...   20201231.0  20201231.0
# std       NaN    374.666984  ...          0.0         0.0
# min       NaN  90102.000000  ...   20201231.0  20201231.0
# 25%       NaN  91201.000000  ...   20201231.0  20201231.0
# 50%       NaN  91201.000000  ...   20201231.0  20201231.0
# 75%       NaN  91201.000000  ...   20201231.0  20201231.0
# max       NaN  92106.000000  ...   20201231.0  20201231.0
#
# [8 rows x 10 columns]

# %% [markdown]
# # 데이터 분석

# %%
Shopping.head()
# Out:
#                  id lclas  ...                      FILE_NAME  base_ymd
# 0  KC506PP19N000001    장소  ...  KC_506_DMSTC_MCST_SHOPNG_2020  20201231
# 1  KC506PP19N000002    장소  ...  KC_506_DMSTC_MCST_SHOPNG_2020  20201231
# 2  KC506PP19N000003    장소  ...  KC_506_DMSTC_MCST_SHOPNG_2020  20201231
# 3  KC506PP19N000004    장소  ...  KC_506_DMSTC_MCST_SHOPNG_2020  20201231
# 4  KC506PP19N000005    장소  ...  KC_506_DMSTC_MCST_SHOPNG_2020  20201231
#
# [5 rows x 27 columns]

# %%
# 어떤 columns 들이 있는지 확인하기
print(Shopping.columns)
# Out:
# Index(['id', 'lclas', 'mlsfc', 'id_poi', 'poi_nm', 'branch_nm', 'sub_nm',
#        'mcate_cd', 'mcate_nm', 'pnu', 'sido_nm', 'sgg_nm', 'bemd_nm', 'ri_nm',
#        'beonji', 'badm_cd', 'hadm_cd', 'rd_cd', 'rd_nm', 'bld_num', 'x', 'y',
#        'grid_cd', 'lst_updt_dt', 'data_orgn', 'FILE_NAME', 'base_ymd'],
#       dtype='object')

# %% [markdown]
# 내가 해야하는 작업을 정의하기
# 1. 지역 별로 장소 분류하기. ( 시? 구? 동?)
# 2. 가게별로 특징 > 장소 > 쇼핑 > 분류코드 or 분류명으로 tidy Data 만들기
# 3. 프랜차이즈인가 아니면 로컬가게인가?
#
# 알게 된 점 정리하기
# 1. 가게이름에 상회, 마트, 유통?? 등등 지역슈퍼로 분리되니 가게이름 X
# 2. 대형할인 vs 대기업마트 vs 지역마트를 구별하는 것은 macte_nm 으로 분류함.
# 3. branch_nm을 통해서 지점이 있는지 확인할 것
#   - 지점이 있다는 것은 유통마트로 볼 것.
# 4. 지역은 시/도 군별로만 분류하기.
#
#
# 우선은 기간별로 방문자를 정리하기
# 공휴일/기간별 기준으로 데이터를 저장하기.
#
# 공휴일과 축제기간을 정리해서, 유의미한 결과?
#
# 역을 지역으로 묶음 ->

# %% [markdown]
# null 데이터 측정해보기.

# %%
Shopping.sample(5)

# %%
classes = Shopping['lclas']
cate = Shopping['mlsfc']
name = Shopping['poi_nm']
market_cate = Shopping['mcate_nm']
local = Shopping['sido_nm']

output = pd.DataFrame({'이름' : name, '지역': local, '클래스': classes, '카테고리' : cate , '세부분류' : market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Shopping.csv', index=False)

# %%
# 데이터 파일 받아오기
Food  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 지역별 문화체육관광시설 인근 음식점(한식, 일식, 양식, 외국식 등) 데이터.csv')
#훈련시킬 데이터 확인하기.
Food.head()

# %%
Food_classes = Food['lclas']
Food_cate = Food['mlsfc']
Food_name = Food['poi_nm']
Food_market_cate = Food['mcate_nm']
Food_local = Food['sido_nm']

output = pd.DataFrame({'이름' : Food_name, '지역': Food_local, '클래스': Food_classes, '카테고리' : Food_cate , '세부분류' : Food_market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Food.csv', index=False)

# %%
# 데이터 파일 받아오기
Cafe  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 문화체육관광시설 인근 카페 및 디저트 판매시설 데이터.csv')
#훈련시킬 데이터 확인하기.
Cafe.head()

# %%
Cafe_classes = Cafe['lclas']
Cafe_cate = Cafe['mlsfc']
Cafe_name = Cafe['poi_nm']
Cafe_market_cate = Cafe['mcate_nm']
Cafe_local = Cafe['sido_nm']

output = pd.DataFrame({'이름' : Cafe_name, '지역': Cafe_local, '클래스': Cafe_classes, '카테고리' : Cafe_cate , '세부분류' : Cafe_market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Cafe.csv', index=False)

# %%
# 데이터 파일 받아오기
Museum  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 문화체육관광 분야 박물관 시설 및 소장자료 통계 데이터(방문객 등 통계 포함).csv')
#훈련시킬 데이터 확인하기.
Museum.head()

# %%
Museum_classes = Museum['lclas']
Museum_cate = Museum['mlsfc']
Museum_name = Museum['fclt_name']

Museum_local = Museum['ctprvn_nm']
Museum_people = Museum['fyer_usemem_tot']
Museum_div = Museum['sdiv']
Museum_fee = Museum['osvc_av_gud_fee']


output = pd.DataFrame({'이름' : Museum_name, '지역': Museum_local, '클래스': Museum_classes, '카테고리' : Museum_cate , '국공립/시립' : Museum_div, '비용' :  Museum_fee, '연방문인원' : Museum_people })
output.to_csv('/content/drive/MyDrive/빅데이터/Museum.csv', index=False)

# %%
# 데이터 파일 받아오기
Sleeping  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 지역별 문화체육관광시설 인근 숙박시설 데이터.csv')
#훈련시킬 데이터 확인하기.
Sleeping.head()

# %%
Sleeping_classes = Sleeping['lclas']
Sleeping_cate = Sleeping['mlsfc']
Sleeping_name = Sleeping['poi_nm']
Sleeping_market_cate = Sleeping['mcate_nm']
Sleeping_local = Sleeping['sido_nm']

output = pd.DataFrame({'이름' : Sleeping_name, '지역': Sleeping_local, '클래스': Sleeping_classes, '카테고리' : Sleeping_cate , '세부분류' : Sleeping_market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Sleeping.csv', index=False)

# %%
# 데이터 파일 받아오기
Drama  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 지역별 영화 드라마 촬영장소 및 시설 데이터(시군구 행정동 100미터격자코드 포함).csv')
#훈련시킬 데이터 확인하기.
Drama.head()

# %%
_classes = Drama['lclas']
_cate = Drama['mlsfc']
_name = Drama['poi_nm']
_market_cate = Drama['mcate_nm']
_local = Drama['sido_nm']

output = pd.DataFrame({'이름' : _name, '지역': _local, '클래스': _classes, '카테고리' : _cate , '세부분류' : _market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Drama.csv', index=False)

# %%
# 데이터 파일 받아오기
Historical  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 지역별 유적지(고궁,성,문,고택,생가,민속마을,유적사적 등) 데이터.csv')
#훈련시킬 데이터 확인하기.
Historical.head()

# %%
_classes = Historical['lclas']
_cate = Historical['mlsfc']
_name = Historical['poi_nm']
_market_cate = Historical['mcate_nm']
_local = Historical['sido_nm']

output = pd.DataFrame({'이름' : _name, '지역': _local, '클래스': _classes, '카테고리' : _cate , '세부분류' : _market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Historical.csv', index=False)

# %%
# 데이터 파일 받아오기
Cinema  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 문화체육관광 분야 영화관 시설 데이터(시군구 행정동 100미터격자코드 포함).csv')
#훈련시킬 데이터 확인하기.
Cinema.head()

# %%
_classes = Cinema['lclas']
_cate = Cinema['mlsfc']
_name = Cinema['poi_nm']
_market_cate = Cinema['mcate_nm']
_local = Cinema['sido_nm']

output = pd.DataFrame({'이름' : _name, '지역': _local, '클래스': _classes, '카테고리' : _cate , '세부분류' : _market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Cinema.csv', index=False)

# %%
# 데이터 파일 받아오기
Exhibition  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 문화체육관광 분야 전시관 시설 데이터(시군구 행정동 100미터격자코드 포함).csv')
#훈련시킬 데이터 확인하기.
Exhibition.head()

# %%
_classes = Exhibition['lclas']
_cate = Exhibition['mlsfc']
_name = Exhibition['poi_nm']
_market_cate = Exhibition['mcate_nm']
_local = Exhibition['sido_nm']

output = pd.DataFrame({'이름' : _name, '지역': _local, '클래스': _classes, '카테고리' : _cate , '세부분류' : _market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Exhibition.csv', index=False)

# %%
# 데이터 파일 받아오기
Parking  = pd.read_csv('/content/drive/MyDrive/빅데이터/data/국내 문화체육관광 분야 국립도립군립 및 도시내 공원 데이터.csv')
#훈련시킬 데이터 확인하기.
Parking.head()

# %%
_classes = Parking['lclas']
_cate = Parking['mlsfc']
_name = Parking['poi_nm']
_market_cate = Parking['mcate_nm']
_local = Parking['sido_nm']

output = pd.DataFrame({'이름' : _name, '지역': _local, '클래스': _classes, '카테고리' : _cate , '세부분류' : _market_cate })
output.to_csv('/content/drive/MyDrive/빅데이터/Parking.csv', index=False)
